# %%
import matplotlib.pyplot as plt

data = [20, 30, 40]
x = [1, 2, 3]
plt.plot(x, data)
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot(['kim', 'lee', 'kang'], [85, 88, 90])

plt.title('English Score of three students')
plt.xlabel('Student name')
plt.ylabel('score')

plt.show()

# %%
import matplotlib.pyplot as plt

xdata = ['Alpha', 'Beta', 'Gamma']
ydata = [90, 85, 88]
plt.plot(xdata, ydata)

plt.title('Korean score of three students')
plt.xlabel('Name')
plt.ylabel('Score')

plt.show()

# %%
import matplotlib.pyplot as plt

xdata = ['Armon', 'Becky', 'Christopher']
ydata1 = [90, 85, 88]
ydata2 = [83, 88, 91]
plt.plot(xdata, ydata1, label='Korean')
plt.plot(xdata, ydata2, label='English')
plt.legend(loc='upper center')

plt.title('Korean and English score of three students')

plt.show()

# %%
import matplotlib.pyplot as plt

xdata = ['Akira', 'Bohemian', 'Caesar']
ydata1 = [90, 85, 88]
ydata2 = [83, 88, 91]
ydata3 = [85, 97, 78]
ydata4 = [92, 88, 82]
plt.plot(xdata, ydata1, label='Korean', color='red', linestyle='-', marker='o')
plt.plot(xdata, ydata2, label='English', color='#00ffff', linestyle='--', marker='x')
plt.plot(xdata, ydata3, label='Math', color='magenta', linestyle='-.', marker='s')
plt.plot(xdata, ydata4, label='Social Study', color='#444444', linestyle=':', marker='d')

plt.title('Scores of four students')
plt.legend(loc='best')

plt.show()

# %%
import matplotlib.pyplot as plt

xdata = list(range(30))
ydata = []

for x in xdata:
    y = 2 * x
    ydata.append(y)

plt.plot(xdata, ydata, label='y=2x')
plt.xlim(0, 35)
plt.ylim(0, 70)
plt.xticks(list(range(0, 35, 2)))
plt.yticks(list(range(0, 70, 5)))

plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

x = ['Amy', 'Brian', 'Charlie']
y = [3, 1, 5]
plt.title('Number of movie watching per year')
plt.bar(x, y)
plt.ylabel('Number')
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib import rc

rc('font', family='Malgun Gothic')

x = ['월', '화', '수', '목', '금', '토', '일']
y = [6.5, 5.7, 5.5, 6.7, 6.3, 7.5, 8.3]
plt.title('연간 요일별 평균 수면시간')
plt.scatter(x, y)
plt.ylabel('수면시간')
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib import rc

rc('font', family='Malgun Gothic')

pets = ['개', '고양이', '기타', '기르지않음']
portion = [18, 3.4, 3.1, 75.5]

plt.pie(portion, explode=(0, 0.1, 0, 0), labels=pets, autopct='%1.1f%%', shadow=True, startangle=90)
plt.title('총 가구 대비 반려동물 기르는 비율(2018)')

plt.show()

# %%
import matplotlib.pyplot as plt

date = list(range(1, 11))
min_temp = [7.3, 3.5, 7.2, 4.5, 3.5, 8.3, 7.7, 6.4, 9.3, 6.3]
max_temp = [15, 16.3, 15.2, 17.5, 18.3, 20.0, 18.8, 17.5, 14.2, 15.3]

plt.plot(date, min_temp, label='Min Temperature', color='red', linestyle='-', marker='o')
plt.plot(date, max_temp, label='Max Temperature', color='blue', linestyle='-.', marker='x')

plt.legend(loc='best')
plt.xlabel('date')
plt.ylabel('temperature')
plt.title('Min and max temperature of ten days')

plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib import rc

rc('font', family='Malgun Gothic')

xdata = ['안지영', '홍지수', '황예린']
ydata1 = [90, 85, 88]
ydata2 = [83, 88, 91]
ydata3 = [85, 97, 78]
ydata4 = [92, 88, 82]
plt.plot(xdata, ydata1, label='국어', color='red', linestyle='--', marker='o')
plt.plot(xdata, ydata2, label='영어', color='cyan', linestyle='-', marker='x')
plt.plot(xdata, ydata3, label='수학', color='violet', linestyle='-.', marker='s')
plt.plot(xdata, ydata4, label='사회', color='blue', linestyle=':', marker='d')

plt.ylim(0, 100)
plt.title('세명 학생의 네 과목 성적')
plt.legend(loc='best')

plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib import rc
import random

rc('font', family='Malgun Gothic')

def make_random_list(num):
    result=[]
    for i in range(num):
        result.append(random.randrange(1, 7))
    return result

count = 10
y = make_random_list(count)
x = list(range(1, 11))

plt.title('주사위 던지기')
plt.bar(x, y)
plt.xticks(x)
plt.yticks([1, 2, 3, 4, 5, 6])
plt.xlabel('던진횟수')
plt.ylabel('주사위 눈')

plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib import rc

rc('font', family='Malgun Gothic')

x = list(range(1, 11))
y = list(range(10, 101, 10))

fig, axs = plt.subplots(nrows=2, ncols=2, figsize=(9, 5), sharex=True, sharey=True)
ax = axs[0][0]
ax.plot(x, y)
ax.set_title('선 그래프1')

ax = axs[0][1]
ax.plot(x,y, color='red', linestyle='--', marker='o')
ax.set_title('선 그래프2')

ax = axs[1][0]
ax.bar(x, y)
ax.set_title('막대그래프')

ax = axs[1][1]
ax.scatter(x, y)
ax.set_title('산포 그래프')

plt.subplots_adjust(left=0.1, right=0.9, bottom=0.1, top=0.9, wspace=0.2, hspace=0.3)

plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib import rc

rc('font', family='Malgun Gothic')

x = ['월', '화', '수', '목', '금', '토', '일']
y1 = [6.5, 5.7, 5.5, 6.7, 6.3, 7.5, 8.3]
y2 = [6.3, 7.7, 7.5, 7.7, 6.2, 7.3, 8.5]

fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(9, 3), sharex=True, sharey=True)
ax = axs[0]
ax.scatter(x, y1)
ax.set_title('2018')

ax = axs[1]
ax.scatter(x, y2)
ax.set_title('2019')

fig.suptitle('연간 요일별 평균 수면시간')

plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib import rc

rc('font', family= 'Malgun Gothic')

x = ['영희', '철수', '건우', '정석']
y = [165, 176, 172, 188]
plt.title('네 명의 키')
plt.bar(x, y)
plt.ylabel('cm')

plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib import rc

rc('font', family='Malgun Gothic')

pets = ['1학년', '2학년', '3학년', '4학년']
portion = [49, 51, 99, 96]

plt.pie(portion, explode=(0, 0, 0.5, 0), labels=pets, autopct='%1.1f%%', shadow=True, startangle=90)
plt.title('경찰대학 총원(2022)')

plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib import rc

rc('font', family='Malgun Gothic')

date = list(range(1, 11))
min_temp = [7.3, 3.5, 7.2, 4.5, 8.5, 5.3, 7.0, 6.4, 9.3, 6.3]
max_temp = [19, 16.3, 25.2, 17.5, 19.3, 17.0, 24.8, 17.5, 24.2, 15.3]

plt.plot(date, min_temp, label='의미 없는 정보', color='purple', linestyle='--', marker='d')
plt.plot(date, max_temp, label='의미 있는 정보', color='yellow', linestyle=':', marker='*')

plt.legend(loc='best')
plt.xlabel('가로')
plt.ylabel('세로')
plt.title('두둥')

plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib import rc

rc('font', family='Malgun Gothic')

num = list(range(1, 10))
A = [15, 5, 7.2, 5.3, 8.5, 5.3, 7.2, 5, 15]
B = [15, 16.3, 25.2, 17.5, 19.3, 17.5, 25.2, 16.3, 15]

plt.plot(num, A, label='아래', color='black', linestyle='--', marker='d')
plt.plot(num, B, label='위', color='black', linestyle='-.', marker='o')

plt.legend(loc='best')
plt.xlabel('가로')
plt.ylabel('세로')
plt.title('늑대의 얼굴')

plt.show()

# %%
import matplotlib.pyplot as plt

pets = ['o', 'o', 'o', 'o']
portion = [1, 1, 1, 1]

plt.pie(portion, explode=(0.2, 0.2, 0.2, 0.2), labels=pets, autopct='%1.1f%%', shadow=False, startangle=60)
plt.title('분열')

plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib import rc

rc('font', family='Malgun Gothic')

x = list(range(1, 11))
y = list(range(10, 101, 10))

fig, axs = plt.subplots(nrows=2, ncols=3, figsize=(5, 5), sharex=True, sharey=True)
ax = axs[0][0]
ax.plot(x,y, color='orange', linestyle='--', marker='o')
ax.set_title('왼쪽 위')

ax = axs[0][1]
ax.plot(x,y, color='cyan', linestyle='-', marker='p')
ax.set_title('가운데 위')

ax = axs[1][0]
ax.plot(x,y, color='violet', linestyle=':', marker='d')
ax.set_title('왼쪽 아래')

ax = axs[1][1]
ax.plot(x,y, color='green', linestyle='-.', marker='x')
ax.set_title('가운데 아래')

ax = axs[0][2]
ax.plot(x,y, color='navy', linestyle='-', marker='*')
ax.set_title('오른쪽 위')

ax = axs[1][2]
ax.plot(x,y, color='black', linestyle='--', marker='s')
ax.set_title('오른쪽 아래')

plt.subplots_adjust(left=0.1, right=0.9, bottom=0.5, top=1, wspace=0.2, hspace=0.3)

plt.show()
